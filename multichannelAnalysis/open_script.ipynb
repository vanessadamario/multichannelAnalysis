# %%
import os
from scipy.io import loadmat

# %%
path = "/home/vanessa/DATA_SEEG/MAT_FILE/"

# %%
listdata = [f for f in os.listdir(path) if f.split("_")[-1] == "channels.mat"]

# %%
listchannels = [f.split("_")[0]+"_channels_name.mat" for f in listdata]

# %%
for (d, l) in zip(listdata, listchannels):
    
    timeseries = loadmat(path + d)["data"]
    label = loadmat(path + l)["alpha_ordered"]
    print(label)
# Out:
# [[array([u'D01-D02'],
#       dtype='<U7')
#   array([u'D02-D03'],
#       dtype='<U7')
#   array([u'D03-D04'],
#       dtype='<U7')
#   array([u'D04-D05'],
#       dtype='<U7')
#   array([u'D05-D06'],
#       dtype='<U7')
#   array([u'D06-D07'],
#       dtype='<U7')
#   array([u'D07-D08'],
#       dtype='<U7')
#   array([u'D08-D09'],
#       dtype='<U7')
#   array([u'F01-F02'],
#       dtype='<U7')
#   array([u'F02-F03'],
#       dtype='<U7')
#   array([u'F03-F04'],
#       dtype='<U7')
#   array([u'F04-F05'],
#       dtype='<U7')
#   array([u'F05-F06'],
#       dtype='<U7')
#   array([u'F06-F07'],
#       dtype='<U7')
#   array([u'F07-F08'],
#       dtype='<U7')
#   array([u'F08-F09'],
#       dtype='<U7')
#   array([u'F09-F10'],
#       dtype='<U7')
#   array([u'F10-F11'],
#       dtype='<U7')
#   array([u'F11-F12'],
#       dtype='<U7')
#   array([u'F12-F13'],
#       dtype='<U7')
#   array([u'H01-H02'],
#       dtype='<U7')
#   array([u'H02-H03'],
#       dtype='<U7')
# ...

# %%
# !jupyter nbconvert open_script.ipynb --to script
# Out:
# [NbConvertApp] Converting notebook open_script.ipynb to script
# [NbConvertApp] Writing 517 bytes to open_script.py
